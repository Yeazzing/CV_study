# %%
from dataset import *
from pathlib import Path 
import albumentations
from torchvision.transforms import ToTensor, ToPILImage

# %%
data = "/workspace/CV_study/ViT/data"

transform_train=albumentations.Compose([
            albumentations.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
            albumentations.Resize(height = 224, width = 224),
            albumentations.pytorch.transforms.ToTensorV2()
            ])

train_data = Dataset(data, "train", transform_train)
val_data = Dataset(data, "val", transform_train)

# %%
tf_toPILImage = ToPILImage()
img_PIL_from_Tensor = tf_toPILImage(train_data[0]['image'])

# %%
img_PIL_from_Tensor
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
